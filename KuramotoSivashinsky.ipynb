# %% [markdown]
# # Kuramoto-Sivashinsky equation
#
# \begin{cases}
# \dfrac{\partial u(x,t)}{\partial t} + \dfrac{\partial^2 u(x,t)}{\partial x^2} + \nu\dfrac{\partial^4 u(x,t)}{\partial x^4} + u(x,t)\dfrac{\partial u(x,t)}{\partial x} = 0 \qquad &\mathrm{in } \ (0,L) \times (0,T)
# \\[7pt]
# u(0,t) = u(L,t) \qquad &\mathrm{on } \ \{x=0,x=L\} \times (0,T)
# \\[7pt]
# \dfrac{\partial u(0,t)}{\partial x} = \dfrac{\partial u(L,t)}{\partial x} \qquad &\mathrm{on } \ \{x=0,x=L\} \times (0,T)
# \\[7pt]
# \dfrac{\partial^2 u(0,t)}{\partial x^2}  = \dfrac{\partial^2 u(L,t)}{\partial x^2} \qquad &\mathrm{on } \ \{x=0,x=L\} \times (0,T)
# \\[7pt]
# \dfrac{\partial^3 u(0,t)}{\partial x^3} = \dfrac{\partial^3 u(L,t)}{\partial x^3} \qquad &\mathrm{on } \ \{x=0,x=L\} \times (0,T)
# \\[7pt]
# u(x,0) = \cos \left( \frac{2 \pi \omega}{L}x \right) \left(1 + \sin \left( \frac{2 \pi \omega}{L}x \right) \right) \qquad & \mathrm{in} \ (0,L) \times \{t=0\}
# \end{cases}
#
#
# where $L$ is the domain length, $T > 0$ is the final time, $u: [0,L] \times [0,T] \to \mathbb{R}$ is the unknown field, $\nu$ is the viscosity and $\omega$ is the initial condition frequency

# %%
#IMPORT LIBRARIES

import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from __future__ import print_function
from IPython.display import clear_output as clc
import cmcrameri.cm as cmc

plt.style.use('default')

# %%
# DOMAIN DISCRETIZATION

nstate = 100
L = 22
x = np.linspace(0, L, nstate)

# %%
# DEFINE THE STATE PROBLEM SOLVER

from tqdm import tqdm

def compute_state(nu, omega, dt, T, nstepsoutput = 300):
    """
    Compute the state trajectory
    Input: viscosity, initial condition frequency, time step, final time and number of steps to return
    Output: time-dependent state
    Credits: https://github.com/E-Renshaw/kuramoto-sivashinsky
    """

    u0 = lambda x: np.cos(omega * 2 * np.pi * x / L) * (1 + np.sin(omega * 2 * np.pi * x / L)) # initial condition

    v = np.fft.fft(u0(x))
    
    # Scalars for the Exponential Time Differencing fourth-order Runge-Kutta (ETDRK4)
    domain_length = x[-1] - x[0]
    k = 2 * np.pi / domain_length * np.transpose(np.conj(np.concatenate((np.arange(0, nstate/2), np.array([0]), np.arange(-nstate/2+1, 0))))) 
    l = k**2 - nu * k**4
    E = np.exp(dt*l)
    E2 = np.exp(dt*l/2)
    
    M = 16
    r = np.exp(1j*np.pi*(np.arange(1, M+1)-0.5) / M)
    LR = dt*np.transpose(np.repeat([l], M, axis=0)) + np.repeat([r], nstate, axis=0)
    Q  = dt*np.real(np.mean((np.exp(LR/2)-1)/LR, axis=1))
    f1 = dt*np.real(np.mean((-4-LR+np.exp(LR)*(4-3*LR+LR**2))/LR**3, axis=1))
    f2 = dt*np.real(np.mean((2+LR+np.exp(LR)*(-2+LR))/LR**3, axis=1))
    f3 = dt*np.real(np.mean((-4-3*LR-LR**2+np.exp(LR)*(4-LR))/LR**3, axis=1))
    
    u = np.array([u0(x)])
    ntimesteps = round(T / dt)
    freqoutput = round((T / nstepsoutput) / dt)
    g = -0.5j*k
    
    for i in tqdm(range(1, ntimesteps + 1), colour = "cyan", file = sys.stdout, bar_format = 'Computing state |{bar}| {n}/{total} {elapsed}<{remaining}'):
        Nv = g*np.fft.fft(np.real(np.fft.ifft(v))**2)
        a = E2*v + Q*Nv
        Na = g*np.fft.fft(np.real(np.fft.ifft(a))**2)
        b = E2*v + Q*Na
        Nb = g*np.fft.fft(np.real(np.fft.ifft(b))**2)
        c = E2*a + Q*(2*Nb-Nv)
        Nc = g*np.fft.fft(np.real(np.fft.ifft(c))**2)
        v = E*v + Nv*f1 + 2*(Na+Nb)*f2 + Nc*f3
        if i % freqoutput == 0:
            un = np.real(np.fft.ifft(v))
            u = np.append(u, np.array([un]), axis=0)
            
    return torch.from_numpy(u)

# %%
# SOLVE THE STATE PROBLEM

dt = 1e-2
T = 200.0
nstepsoutput = 200

nu = 1.5
omega = 3.0
        
ut = compute_state(nu, omega, dt, T, nstepsoutput)
ut.t()
# Out:
# Computing state |██████████| 20000/20000 00:00<00:00
# tensor([[1.0000, 0.9638, 0.8998,  ..., 1.9101, 1.9251, 1.8765],
#         [1.1678, 0.9551, 0.8940,  ..., 1.8225, 1.8780, 1.8560],
#         [1.2734, 0.9090, 0.8536,  ..., 1.6744, 1.7695, 1.7754],
#         ...,
#         [0.5833, 0.8140, 0.7554,  ..., 1.8794, 1.7876, 1.6755],
#         [0.7961, 0.8906, 0.8281,  ..., 1.9325, 1.8724, 1.7781],
#         [1.0000, 0.9442, 0.8797,  ..., 1.9476, 1.9235, 1.8505]],
#        dtype=torch.float64)

# %%
# STATE TRAJECTORY (PLOT)

def plot_state(u, cmap = cmc.vik, title = None, fontsize = None, ticks = True, colorbar = True, levels = 50, vmax = None, vmin = None):
    """
    State trajectory
    Input: state trajectory with dimension (ntimes, nstate) and plot functionalities
    """

    times = np.linspace(0, T, u.shape[0])
    timesgrid, xgrid = np.meshgrid(times, x)
    
    fig = plt.contourf(timesgrid, xgrid, u.t(), cmap = cmap, levels = levels, vmax = vmax, vmin = vmin)
    
    plt.xlabel(r"Time $t$", fontsize = fontsize)
    plt.ylabel(r"Space $x$", fontsize = fontsize)
    plt.xlim(times[0], times[-1])
    plt.ylim((x[0], x[-1]))
    plt.title(title, fontsize = fontsize)

    if not ticks:
        plt.xticks([], [])
        plt.yticks([], [])
        
    if colorbar:
        plt.colorbar(fig)

plt.figure(figsize = (8,4))
plot_state(ut, colorbar = False, title = "State trajectory")

# %% [markdown]
# # Snapshots generation

# %%
# GENERATE SNAPSHOTS (SKIP THIS CELL IF DATA ALREADY AVAILABLE)

dt = 1e-2
T = 200.0
nstepsoutput = 200
ntimes = nstepsoutput + 1 # Time series length

ntrajectories = 500
nparams = 2

params_range = [(1.0, 2.0), (1.0, 5.0)] # Physical parameters: viscosity and initial condition frequency

device = torch.device("mps" if torch.mps.is_available() else "cpu")

filename = 'KuramotoSivashinsky_data'
U = torch.zeros(ntrajectories, ntimes, nstate)
MU = torch.zeros(ntrajectories, ntimes, nparams)

for i in range(ntrajectories):

    print(f"Generating snapshots n.{i}...")
    
    params = [0] * len(params_range)
    for j in range(len(params_range)):
        params[j] = ((params_range[j][1] - params_range[j][0]) * torch.rand(1) + params_range[j][0]).item()  
    
    ut = compute_state(params[0], params[1], dt, T, nstepsoutput)

    U[i] = ut
    
    for j in range(ntimes):
        MU[i,j] = torch.tensor(params)

    clc(wait = True)

print("Snapshots generated!")

np.savez("%s.npz" % filename.replace(".npz",""), u = U, mu = MU)

# %%
# LOAD SNAPSHOTS MATRICES
device = torch.device("mps" if torch.mps.is_available() else "cpu")


dt = 1e-2
T = 200.0
nstepsoutput = 200
ntimes = nstepsoutput + 1 # Time series length

ntrajectories = 500
nparams = 2

filename = 'KuramotoSivashinsky_data'
Data = np.load("%s.npz" % filename.replace(".npz",""))
U = torch.tensor(Data["u"])
MU = torch.tensor(Data["mu"])

del Data

# %%
U = U.to(device)
Mu = MU.to(device)

# %%
# TRAJECTORY EXAMPLE (PLOT)

which = 0

plt.figure(figsize = (8,4))
plot_state(U[which].detach().cpu(), colorbar = False, title = "State trajectory")

# %%
# TRAJECTORY EXAMPLES (PLOT)

from utils.processdata_torch import multiplot

which = (0, 1, 2)
plotlist = [U[which[0]].detach().cpu(), U[which[1]].detach().cpu(), U[which[2]].detach().cpu()]

plot_state_wrapper = lambda u: plot_state(u, colorbar = False, fontsize = 16)

multiplot(plotlist, plot_state_wrapper, titles = ("Trajectory 1", "Trajectory 2", "Trajectory 3"), fontsize = 16, figsize = (30,5), axis = True)

# %%
# TRAIN-VALIDATION-TEST SPLITTING

np.random.seed(0)

ntrajectories = 100
ntrain = round(0.8 * ntrajectories)

idx_train = np.random.choice(ntrajectories, size = ntrain, replace = False)
mask = np.ones(ntrajectories)
mask[idx_train] = 0
idx_valid_test = np.arange(0, ntrajectories)[np.where(mask!=0)[0]]
idx_valid = idx_valid_test[::2]
idx_test = idx_valid_test[1::2]

nvalid = idx_valid.shape[0]
ntest = idx_test.shape[0]

Utrain = U[idx_train]
Uvalid = U[idx_valid]
Utest = U[idx_test]
MUtrain = MU[idx_train]
MUvalid = MU[idx_valid]
MUtest = MU[idx_test]

del U, MU

# %% [markdown]
# # State reduction - POD

# %%
# IMPORT FUNCTIONS FOR COMPUTING ERRORS

from utils.processdata_torch import mre, num2p # Error metrics and format

# %%
# RESHAPE MATRICES

Utrain = Utrain.reshape(-1, nstate).detach().cpu().numpy()
Uvalid = Uvalid.reshape(-1, nstate).detach().cpu().numpy()
Utest = Utest.reshape(-1, nstate).detach().cpu().numpy()

# %%
# PRINCIPAL ORTHOGONAL DECOMPOSITION FOR U

from sklearn.utils.extmath import randomized_svd

kstate = 20 # Number of POD modes

W, S, V = randomized_svd(Utrain, n_components = kstate)

teal = sns.light_palette("teal", 15)
plt.plot([i for i in range(1, kstate + 1)], S, color = teal[14], marker = 's', markersize = 5, linewidth = 1)
plt.ticklabel_format(axis = 'y', style = 'sci', scilimits = (0,0))
plt.loglog(kstate, S[kstate-1], color = teal[14], marker = 's', linestyle = '--')
plt.title("Singular values decay");

Utrain_POD = Utrain @ V.transpose()
Uvalid_POD = Uvalid @ V.transpose()
Utest_POD = Utest @ V.transpose()
Utrain_reconstructed = W @ np.diag(S) @ V
Uvalid_reconstructed = Uvalid @ V.transpose() @ V
Utest_reconstructed = Utest @ V.transpose() @ V

# %%
# POD MODES (PLOT)

plotlist = [V[0], V[1], V[2]]

def plot_mode(u, title = None, colorbar = False):  
    """
    POD mode
    Input: POD mode with dimension (nstate) and plot functionalities
    """

    plt.plot(x, u, color = "magenta", linewidth = 2)
    plt.grid()

multiplot(plotlist, plot_mode, titles = ("First POD mode", "Second POD mode", "Third POD mode"), axis = True, figsize = (15, 5))

# %%
# SCALING

from sklearn.preprocessing import MinMaxScaler

scalerU = MinMaxScaler()
scalerU = scalerU.fit(Utrain_POD)
Utrain_POD = scalerU.transform(Utrain_POD)
Uvalid_POD = scalerU.transform(Uvalid_POD)
Utest_POD = scalerU.transform(Utest_POD)

# %%
# RESHAPE MATRICES

Utrain = torch.from_numpy(Utrain.reshape(ntrain, ntimes, nstate))
Uvalid = torch.from_numpy(Uvalid.reshape(nvalid, ntimes, nstate))
Utest = torch.from_numpy(Utest.reshape(ntest, ntimes, nstate))
Utrain_POD = torch.from_numpy(Utrain_POD.reshape(ntrain, ntimes, kstate))
Uvalid_POD = torch.from_numpy(Uvalid_POD.reshape(nvalid, ntimes, kstate))
Utest_POD = torch.from_numpy(Utest_POD.reshape(ntest, ntimes, kstate))
Utrain_reconstructed = torch.from_numpy(Utrain_reconstructed.reshape(ntrain, ntimes, nstate))
Uvalid_reconstructed = torch.from_numpy(Uvalid_reconstructed.reshape(nvalid, ntimes, nstate))
Utest_reconstructed = torch.from_numpy(Utest_reconstructed.reshape(ntest, ntimes, nstate))

# %%
# POD RECONSTRUCTION ERRORS ON TEST DATA

print("Mean relative POD reconstruction error on U: %s" % num2p(mre(Utest, Utest_reconstructed)))
# Out:
# Mean relative POD reconstruction error on U: 0.63%

# %%
# FOM vs POD RECONSTRUCTION (PLOTS)

which = -1

plotlist = [Utest[which], Utest_reconstructed[which], ((Utest[which] - Utest_reconstructed[which])**2).sqrt()]
vmin = min(plotlist[i].min() for i in range(len(plotlist)))
vmax = max(plotlist[i].max() for i in range(len(plotlist)))

plot_state_wrapper = lambda u: plot_state(u, colorbar = False, fontsize = 16, vmin = vmin, vmax = vmax)

multiplot(plotlist, plot_state_wrapper, titles = ("State trajectory", "POD reconstruction", "Reconstruction error"), fontsize = 16, figsize = (30, 5), axis = True)

# %% [markdown]
# # SHRED-ROM

# %%
# EXTRACT SENSORS DATA (SKIP THIS CELL IF DATA ALREADY AVAILABLE)

nsensors = 3
idx_sensors = np.random.choice(nstate, size = nsensors, replace = False)
sensors_coordinates = x[idx_sensors]

sensors_data_train = Utrain[:,:,idx_sensors]
sensors_data_valid = Uvalid[:,:,idx_sensors]
sensors_data_test = Utest[:,:,idx_sensors]

# %%
# TRAJECTORY WITH SENSORS (PLOT) 

def trajectory_with_sensors(ut, sensors_coordinates, cmap = cmc.vik, title = None, fontsize = None, ticks = True, colorbar = False, levels = 50, vmax = None, vmin = None):
    """
    State trajectory with sensors
    Input: state trajectory with dimension (ntimes, nstate), sensors coordinates with dimension (nsensors) and plot functionalities
    """

    ntimes = ut.shape[0]
    times = np.linspace(0, T, ntimes)
    step = 10

    for i in np.arange(1, ntimes + step, step):
        
        plt.figure(figsize = (8,4))

        timesgrid, xgrid = np.meshgrid(times[:i+1], x)        
        
        plt.contourf(timesgrid, xgrid, ut[:i+1].t(), cmap = cmap, levels = levels, vmax = vmax, vmin = vmin)

        plt.xlabel(r"Time $t$", fontsize = fontsize)
        plt.ylabel(r"Space $x$", fontsize = fontsize)
        plt.xlim(times[0], times[-1])
        plt.ylim((x[0], x[-1]))
        plt.title(title, fontsize = fontsize)

        if not ticks:
            plt.xticks([], [])
            plt.yticks([], [])
        
        if colorbar:
            plt.colorbar(fig)

        if i < ntimes:
            for k in range(nsensors):
                plt.plot(i, sensors_coordinates[k], 'o', mfc = 'magenta', mec = 'black', ms = 10, mew = 1.5)

        display(plt.gcf())
        plt.close()
        clc(wait = True)

which = 0

trajectory_with_sensors(Utrain[which], sensors_coordinates, title = "State trajectory with sensors", ticks = False)

# %%
# BUILD TRAIN, VALIDATION AND TEST DATASETS WITH PADDING

from utils.processdata_torch import Padding, TimeSeriesDataset

device = torch.device("mps" if torch.mps.is_available() else "cpu")
print("Using device:", device)

lag = 50

train_data_in = Padding(sensors_data_train, lag).to(device)
valid_data_in = Padding(sensors_data_valid, lag).to(device)
test_data_in = Padding(sensors_data_test, lag).to(device)

train_data_out = Padding(Utrain_POD, 1).squeeze(1).to(device)
valid_data_out = Padding(Uvalid_POD, 1).squeeze(1).to(device)
test_data_out = Padding(Utest_POD, 1).squeeze(1).to(device)

train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
test_dataset = TimeSeriesDataset(test_data_in, test_data_out)

print(train_data_in.shape)
print(valid_data_in.shape)
print(test_data_in.shape)
# Out:
# Using device: mps
# torch.Size([16080, 50, 3])
# torch.Size([2010, 50, 3])
# torch.Size([2010, 50, 3])

# %%
# SHRED TRAINING (SKIP THIS CELL IF SHRED ALREADY AVAILABLE)

from utils.models import SHRED, fit

shred = SHRED(nsensors, kstate, hidden_size = 64, hidden_layers = 2, decoder_sizes = [350, 400], dropout = 0.1, device=device).to(device)
train_errors, valid_errors = fit(shred, train_dataset, valid_dataset, batch_size = 64, epochs = 100, lr = 1e-3, verbose = True, patience = 100)
# Out:
# Training done: Training loss = 1.99% 	 Validation loss = 3.87%

# %%
plt.plot(train_errors, label = "Train loss")
plt.plot(valid_errors, label = "Validation loss")
plt.yscale('log')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("SHRED training loss")
# Out:
# Text(0.5, 1.0, 'SHRED training loss')

# %%
# SHRED ERRORS ON TEST DATA

shred.freeze()

Utest_POD_hat = shred(test_data_in).cpu()
Utest_hat = torch.from_numpy(scalerU.inverse_transform(Utest_POD_hat)) @ V
Utest_hat = Utest_hat.reshape(ntest, ntimes, nstate)

print("Mean relative SHRED prediction error on U: %s" % num2p(mre(Utest, Utest_hat)))
# Out:
# Mean relative SHRED prediction error on U: 10.77%
# /var/folders/tt/h2vsggv50cv7_km1_pmr2nn00000gn/T/ipykernel_5522/3036502591.py:6: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   Utest_hat = torch.from_numpy(scalerU.inverse_transform(Utest_POD_hat)) @ V

# %%
# TRAJECTORY WITH SENSORS (PLOT) 

def trajectories_with_sensors(uts, sensors_coordinates, cmap = cmc.vik, titles = None, fontsize = None, ticks = True, colorbar = False, levels = 50, vmax = None, vmin = None):
    """
    Trajectories with sensors
    Input: state trajectory with dimension (ntimes, nstate), sensors coordinates with dimension (nsensors) and plot functionalities
    """

    vmin = min(uts[j].min() for j in range(len(uts)))
    vmax = max(uts[j].max() for j in range(len(uts)))

    ntimes = uts[0].shape[0]
    times = np.linspace(0, T, ntimes)
    step = 10
    
    for i in np.arange(1, ntimes + step, step):
        
        plt.figure(figsize = (30, 5))
        
        for j in range(len(uts)):
            
            plt.subplot(1, len(uts), j+1)
        
            timesgrid, xgrid = np.meshgrid(times[:i+1], x)        
        
            plt.contourf(timesgrid, xgrid, uts[j][:i+1].t(), cmap = cmap, levels = levels, vmax = vmax, vmin = vmin)

            plt.xlabel(r"Time $t$", fontsize = fontsize)
            plt.ylabel(r"Space $x$", fontsize = fontsize)
            plt.xlim(times[0], times[-1])
            plt.ylim((x[0], x[-1]))
            plt.title(titles[j], fontsize = fontsize)

            if not ticks:
                plt.xticks([], [])
                plt.yticks([], [])
        
            if colorbar:
                plt.colorbar(fig)

            if i < ntimes and j < len(uts)-1:
                for k in range(nsensors):
                    plt.plot(i, sensors_coordinates[k], 'o', mfc = 'magenta', mec = 'black', ms = 10, mew = 1.5)

        display(plt.gcf())
        plt.close()
        clc(wait = True)

which = 0

plotlist = [Utest[which], Utest_hat[which], ((Utest[which] - Utest_hat[which])**2).sqrt()]

trajectories_with_sensors(plotlist, sensors_coordinates, titles = ("State trajectory", "SHRED prediction", "Prediction error"), fontsize = 16, ticks = False)

# %%
from utils.processdata_jax import Padding, TimeSeriesDataset

device =  torch.device("mps" if torch.cuda.is_available() else "cpu")

lag = 50
train_data_in = Padding(sensors_data_train, lag)
valid_data_in = Padding(sensors_data_valid, lag)
test_data_in = Padding(sensors_data_test, lag)

train_data_out = Padding(Utrain_POD, 1).squeeze(1)
valid_data_out = Padding(Uvalid_POD, 1).squeeze(1)
test_data_out = Padding(Utest_POD, 1).squeeze(1)

train_dataset = TimeSeriesDataset(train_data_in, train_data_out)
train_data = {'S_i':train_dataset.X, 'Y': train_dataset.Y}
valid_dataset = TimeSeriesDataset(valid_data_in, valid_data_out)
valid_data = {'S_i':valid_dataset.X, 'Y': valid_dataset.Y}
test_dataset = TimeSeriesDataset(test_data_in, test_data_out)
test_data = {'S_i':test_dataset.X, 'Y': test_dataset.Y}

print(train_data_in.shape, )
# Out:
# (16080, 50, 3)

# %%
from utils.models_diffrax import *

import importlib
import utils
importlib.reload(utils.models_diffrax)
from utils.models_diffrax import SHRED, fit_SHRED

model_key_shred, = jr.split(jr.PRNGKey(0), 1)
hidden_size = 64
hidden_layers = 10
output_size = train_data['Y'].shape[-1]  # The output dimension is the spatial dimension (200)
print(f"data size ={nsensors}, output_size={output_size}")

shred_2 = SHRED(nsensors, output_size, hidden_size=hidden_size, hidden_layers=hidden_layers, decoder_sizes=[350, 400], activation=jax.nn.gelu, key = model_key_shred, dropout =0.1)

train_loss = []
valid_loss = []
shred_2, train_losses_1, valid_losses_1 = fit_SHRED(shred_2, train_data, valid_data, batch_size=64, steps=300, lr=1e-3, early_stopping=100)
train_loss.extend(train_losses_1)
valid_loss.extend(valid_losses_1)
shred_2, train_losses, valid_losses = fit_SHRED(shred_2, train_data, valid_data, batch_size=64, steps=300, lr=1e-4, early_stopping=100)
train_loss.extend(train_losses)
valid_loss.extend(valid_losses)
# Out:
# data size =3, output_size=20
# 16080 16080
# 16080 16080
# 2010 2010
# 2010 2010
# Step     0 | Train 2.1873e-01 | Valid 1.6941e-01 | LR 1.000e-03 | Time 1.134s | Early stopping counter = 0
# Step     1 | Train 1.7207e-01 | Valid 1.2287e-01 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step     2 | Train 1.2440e-01 | Valid 7.7823e-02 | LR 1.000e-03 | Time 0.125s | Early stopping counter = 0
# Step     3 | Train 7.4456e-02 | Valid 3.2915e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 0
# Step     4 | Train 3.1502e-02 | Valid 2.4308e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step     5 | Train 2.2930e-02 | Valid 4.1383e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step     6 | Train 3.9954e-02 | Valid 3.7459e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 1
# Step     7 | Train 3.4480e-02 | Valid 2.4129e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 2
# Step     8 | Train 2.4237e-02 | Valid 1.9606e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step     9 | Train 1.7992e-02 | Valid 2.3101e-02 | LR 1.000e-03 | Time 0.113s | Early stopping counter = 0
# Step    10 | Train 1.8537e-02 | Valid 2.4055e-02 | LR 1.000e-03 | Time 0.115s | Early stopping counter = 1
# Step    11 | Train 2.2678e-02 | Valid 2.2681e-02 | LR 1.000e-03 | Time 0.112s | Early stopping counter = 2
# Step    12 | Train 2.3044e-02 | Valid 2.1030e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 3
# Step    13 | Train 1.9385e-02 | Valid 1.9289e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 4
# Step    14 | Train 1.7479e-02 | Valid 1.8248e-02 | LR 1.000e-03 | Time 0.113s | Early stopping counter = 0
# Step    15 | Train 1.7118e-02 | Valid 1.7153e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 0
# Step    16 | Train 1.5900e-02 | Valid 1.7212e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 0
# Step    17 | Train 1.6188e-02 | Valid 1.6075e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 1
# Step    18 | Train 1.7656e-02 | Valid 1.6621e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step    19 | Train 1.7623e-02 | Valid 1.6842e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 1
# Step    20 | Train 1.6889e-02 | Valid 1.5032e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 2
# Step    21 | Train 1.5134e-02 | Valid 1.4586e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 0
# Step    22 | Train 1.4229e-02 | Valid 1.6020e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 0
# Step    23 | Train 1.5163e-02 | Valid 1.5278e-02 | LR 1.000e-03 | Time 0.113s | Early stopping counter = 1
# Step    24 | Train 1.6008e-02 | Valid 1.6685e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 2
# Step    25 | Train 1.5561e-02 | Valid 1.6645e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 3
# Step    26 | Train 1.5932e-02 | Valid 1.6129e-02 | LR 1.000e-03 | Time 0.129s | Early stopping counter = 4
# Step    27 | Train 1.4748e-02 | Valid 1.5295e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 5
# Step    28 | Train 1.4985e-02 | Valid 1.6044e-02 | LR 1.000e-03 | Time 0.118s | Early stopping counter = 6
# Step    29 | Train 1.5068e-02 | Valid 1.6203e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 7
# Step    30 | Train 1.5370e-02 | Valid 1.5434e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 8
# Step    31 | Train 1.2888e-02 | Valid 1.5849e-02 | LR 1.000e-03 | Time 0.215s | Early stopping counter = 9
# Step    32 | Train 1.4126e-02 | Valid 1.6055e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 10
# Step    33 | Train 1.5777e-02 | Valid 1.5034e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 11
# Step    34 | Train 1.4844e-02 | Valid 1.6124e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 12
# Step    35 | Train 1.4576e-02 | Valid 1.4989e-02 | LR 1.000e-03 | Time 0.112s | Early stopping counter = 13
# Step    36 | Train 1.3781e-02 | Valid 1.6758e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 14
# Step    37 | Train 1.3416e-02 | Valid 1.4787e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 15
# Step    38 | Train 1.3154e-02 | Valid 1.4401e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 16
# Step    39 | Train 1.3477e-02 | Valid 1.5785e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 0
# Step    40 | Train 1.5015e-02 | Valid 1.6312e-02 | LR 1.000e-03 | Time 0.115s | Early stopping counter = 1
# Step    41 | Train 1.5002e-02 | Valid 1.6123e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 2
# Step    42 | Train 1.4390e-02 | Valid 1.4891e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 3
# Step    43 | Train 1.4104e-02 | Valid 1.5694e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 4
# Step    44 | Train 1.4076e-02 | Valid 1.4244e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 5
# Step    45 | Train 1.4415e-02 | Valid 1.4047e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step    46 | Train 1.4419e-02 | Valid 1.4342e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step    47 | Train 1.5092e-02 | Valid 1.5279e-02 | LR 1.000e-03 | Time 0.130s | Early stopping counter = 1
# Step    48 | Train 1.4614e-02 | Valid 1.5209e-02 | LR 1.000e-03 | Time 0.119s | Early stopping counter = 2
# Step    49 | Train 1.4392e-02 | Valid 1.5692e-02 | LR 1.000e-03 | Time 0.219s | Early stopping counter = 3
# Step    50 | Train 1.4242e-02 | Valid 1.5955e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 4
# Step    51 | Train 1.4314e-02 | Valid 1.5206e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 5
# Step    52 | Train 1.3684e-02 | Valid 1.5021e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 6
# Step    53 | Train 1.4282e-02 | Valid 1.6002e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step    54 | Train 1.3332e-02 | Valid 1.4515e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 8
# Step    55 | Train 1.4202e-02 | Valid 1.6200e-02 | LR 1.000e-03 | Time 0.112s | Early stopping counter = 9
# Step    56 | Train 1.6520e-02 | Valid 1.5501e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 10
# Step    57 | Train 1.5154e-02 | Valid 1.4483e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 11
# Step    58 | Train 1.4302e-02 | Valid 1.4804e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 12
# Step    59 | Train 1.3890e-02 | Valid 1.5194e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 13
# Step    60 | Train 1.3443e-02 | Valid 1.4754e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 14
# Step    61 | Train 1.4104e-02 | Valid 1.4246e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 15
# Step    62 | Train 1.4395e-02 | Valid 1.3786e-02 | LR 1.000e-03 | Time 0.119s | Early stopping counter = 16
# Step    63 | Train 1.3731e-02 | Valid 1.4064e-02 | LR 1.000e-03 | Time 0.099s | Early stopping counter = 0
# Step    64 | Train 1.3701e-02 | Valid 1.5813e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step    65 | Train 1.2852e-02 | Valid 1.5027e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step    66 | Train 1.3523e-02 | Valid 1.5199e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 3
# Step    67 | Train 1.5704e-02 | Valid 1.5598e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 4
# Step    68 | Train 1.4349e-02 | Valid 1.4222e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 5
# Step    69 | Train 1.5384e-02 | Valid 1.5217e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 6
# Step    70 | Train 1.5246e-02 | Valid 1.4330e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step    71 | Train 1.3761e-02 | Valid 1.5063e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 8
# Step    72 | Train 1.3545e-02 | Valid 1.5340e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 9
# Step    73 | Train 1.3656e-02 | Valid 1.4861e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 10
# Step    74 | Train 1.3565e-02 | Valid 1.4176e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 11
# Step    75 | Train 1.5330e-02 | Valid 1.5124e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 12
# Step    76 | Train 1.3996e-02 | Valid 1.3878e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 13
# Step    77 | Train 1.3543e-02 | Valid 1.5748e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 14
# Step    78 | Train 1.4036e-02 | Valid 1.4335e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 15
# Step    79 | Train 1.3517e-02 | Valid 1.2860e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 16
# Step    80 | Train 1.2697e-02 | Valid 1.5264e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step    81 | Train 1.2172e-02 | Valid 1.4678e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step    82 | Train 1.3306e-02 | Valid 1.5895e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 2
# Step    83 | Train 1.2949e-02 | Valid 1.3703e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 3
# Step    84 | Train 1.3743e-02 | Valid 1.3431e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 4
# Step    85 | Train 1.3010e-02 | Valid 1.4219e-02 | LR 1.000e-03 | Time 0.105s | Early stopping counter = 5
# Step    86 | Train 1.4334e-02 | Valid 1.4007e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 6
# Step    87 | Train 1.4664e-02 | Valid 1.2853e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step    88 | Train 1.2873e-02 | Valid 1.2696e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step    89 | Train 1.1632e-02 | Valid 1.1895e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step    90 | Train 1.2076e-02 | Valid 1.4837e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step    91 | Train 1.2431e-02 | Valid 1.4821e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step    92 | Train 1.1923e-02 | Valid 1.1809e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step    93 | Train 1.2163e-02 | Valid 1.4422e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step    94 | Train 1.2610e-02 | Valid 1.2841e-02 | LR 1.000e-03 | Time 0.105s | Early stopping counter = 1
# Step    95 | Train 1.1177e-02 | Valid 1.4963e-02 | LR 1.000e-03 | Time 0.093s | Early stopping counter = 2
# Step    96 | Train 1.3084e-02 | Valid 1.3477e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step    97 | Train 1.2192e-02 | Valid 1.5892e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 4
# Step    98 | Train 1.4140e-02 | Valid 1.2342e-02 | LR 1.000e-03 | Time 0.105s | Early stopping counter = 5
# Step    99 | Train 1.1109e-02 | Valid 1.0901e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 6
# Step   100 | Train 1.2062e-02 | Valid 1.3058e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   101 | Train 1.2391e-02 | Valid 1.3095e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   102 | Train 1.2701e-02 | Valid 1.3011e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step   103 | Train 1.2936e-02 | Valid 1.3915e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 3
# Step   104 | Train 1.3805e-02 | Valid 1.1622e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 4
# Step   105 | Train 1.2213e-02 | Valid 1.3923e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 5
# Step   106 | Train 1.1980e-02 | Valid 1.4562e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 6
# Step   107 | Train 1.2443e-02 | Valid 1.2852e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 7
# Step   108 | Train 1.1387e-02 | Valid 1.2619e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 8
# Step   109 | Train 1.3254e-02 | Valid 1.4156e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 9
# Step   110 | Train 1.1264e-02 | Valid 1.1971e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 10
# Step   111 | Train 1.1652e-02 | Valid 1.1267e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 11
# Step   112 | Train 1.0841e-02 | Valid 1.2089e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 12
# Step   113 | Train 1.2709e-02 | Valid 1.1422e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 13
# Step   114 | Train 1.0887e-02 | Valid 1.0455e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 14
# Step   115 | Train 1.0730e-02 | Valid 1.2921e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   116 | Train 9.5371e-03 | Valid 1.1922e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step   117 | Train 1.1853e-02 | Valid 1.1181e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step   118 | Train 1.0987e-02 | Valid 1.1235e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 3
# Step   119 | Train 9.5937e-03 | Valid 1.0376e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 4
# Step   120 | Train 1.0135e-02 | Valid 1.2427e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 0
# Step   121 | Train 1.0518e-02 | Valid 1.1204e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   122 | Train 1.1724e-02 | Valid 1.1990e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   123 | Train 1.3116e-02 | Valid 9.3579e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step   124 | Train 1.0862e-02 | Valid 1.2123e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   125 | Train 1.1504e-02 | Valid 1.1473e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   126 | Train 1.1377e-02 | Valid 1.0133e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   127 | Train 1.1023e-02 | Valid 1.1630e-02 | LR 1.000e-03 | Time 0.093s | Early stopping counter = 3
# Step   128 | Train 1.0142e-02 | Valid 1.3327e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 4
# Step   129 | Train 1.0994e-02 | Valid 9.2961e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 5
# Step   130 | Train 1.0783e-02 | Valid 1.2920e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step   131 | Train 1.1796e-02 | Valid 1.0957e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   132 | Train 1.0992e-02 | Valid 1.0123e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   133 | Train 1.1746e-02 | Valid 1.1661e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step   134 | Train 1.0202e-02 | Valid 1.0177e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 4
# Step   135 | Train 1.0009e-02 | Valid 9.9883e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 5
# Step   136 | Train 1.2067e-02 | Valid 1.0533e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 6
# Step   137 | Train 1.0214e-02 | Valid 1.0570e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 7
# Step   138 | Train 1.1069e-02 | Valid 1.1518e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 8
# Step   139 | Train 1.1453e-02 | Valid 1.1499e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 9
# Step   140 | Train 9.7862e-03 | Valid 1.1774e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 10
# Step   141 | Train 9.5022e-03 | Valid 9.8061e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 11
# Step   142 | Train 1.1743e-02 | Valid 1.2747e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 12
# Step   143 | Train 1.0967e-02 | Valid 1.0816e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 13
# Step   144 | Train 1.2331e-02 | Valid 1.0076e-02 | LR 1.000e-03 | Time 0.137s | Early stopping counter = 14
# Step   145 | Train 1.1043e-02 | Valid 9.6120e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 15
# Step   146 | Train 1.2036e-02 | Valid 9.7844e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 16
# Step   147 | Train 1.0573e-02 | Valid 1.1562e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 17
# Step   148 | Train 1.0896e-02 | Valid 9.5583e-03 | LR 1.000e-03 | Time 0.121s | Early stopping counter = 18
# Step   149 | Train 8.4725e-03 | Valid 1.0850e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 19
# Step   150 | Train 1.1093e-02 | Valid 1.0334e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 20
# Step   151 | Train 9.6994e-03 | Valid 1.0508e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 21
# Step   152 | Train 9.8754e-03 | Valid 1.0612e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 22
# Step   153 | Train 1.0655e-02 | Valid 1.0651e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 23
# Step   154 | Train 1.0479e-02 | Valid 1.0019e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 24
# Step   155 | Train 1.0610e-02 | Valid 1.0989e-02 | LR 1.000e-03 | Time 0.120s | Early stopping counter = 25
# Step   156 | Train 1.0511e-02 | Valid 1.0115e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 26
# Step   157 | Train 1.2898e-02 | Valid 1.0967e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 27
# Step   158 | Train 9.7987e-03 | Valid 1.0426e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 28
# Step   159 | Train 1.2061e-02 | Valid 1.2261e-02 | LR 1.000e-03 | Time 0.097s | Early stopping counter = 29
# Step   160 | Train 1.0924e-02 | Valid 1.2579e-02 | LR 1.000e-03 | Time 0.104s | Early stopping counter = 30
# Step   161 | Train 1.0545e-02 | Valid 1.0391e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 31
# Step   162 | Train 1.0251e-02 | Valid 9.4644e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 32
# Step   163 | Train 1.0073e-02 | Valid 8.9990e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 33
# Step   164 | Train 1.0745e-02 | Valid 9.7644e-03 | LR 1.000e-03 | Time 0.120s | Early stopping counter = 0
# Step   165 | Train 1.0095e-02 | Valid 9.0405e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   166 | Train 1.0953e-02 | Valid 9.2257e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   167 | Train 8.9438e-03 | Valid 9.8112e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step   168 | Train 1.1272e-02 | Valid 1.1082e-02 | LR 1.000e-03 | Time 0.112s | Early stopping counter = 4
# Step   169 | Train 9.7037e-03 | Valid 1.0149e-02 | LR 1.000e-03 | Time 0.113s | Early stopping counter = 5
# Step   170 | Train 9.1404e-03 | Valid 9.7410e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 6
# Step   171 | Train 1.0434e-02 | Valid 1.0001e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 7
# Step   172 | Train 8.7198e-03 | Valid 1.1471e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 8
# Step   173 | Train 1.2175e-02 | Valid 1.0634e-02 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 9
# Step   174 | Train 1.1080e-02 | Valid 1.1402e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 10
# Step   175 | Train 1.0634e-02 | Valid 1.1417e-02 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 11
# Step   176 | Train 8.2074e-03 | Valid 1.0310e-02 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 12
# Step   177 | Train 1.1318e-02 | Valid 1.0259e-02 | LR 1.000e-03 | Time 0.112s | Early stopping counter = 13
# Step   178 | Train 9.3457e-03 | Valid 9.4326e-03 | LR 1.000e-03 | Time 0.121s | Early stopping counter = 14
# Step   179 | Train 9.5321e-03 | Valid 9.6962e-03 | LR 1.000e-03 | Time 0.132s | Early stopping counter = 15
# Step   180 | Train 8.9505e-03 | Valid 1.0207e-02 | LR 1.000e-03 | Time 0.119s | Early stopping counter = 16
# Step   181 | Train 9.4192e-03 | Valid 8.2301e-03 | LR 1.000e-03 | Time 0.123s | Early stopping counter = 17
# Step   182 | Train 8.9867e-03 | Valid 9.0449e-03 | LR 1.000e-03 | Time 0.120s | Early stopping counter = 0
# Step   183 | Train 9.4399e-03 | Valid 1.0100e-02 | LR 1.000e-03 | Time 0.117s | Early stopping counter = 1
# Step   184 | Train 1.1022e-02 | Valid 9.8737e-03 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 2
# Step   185 | Train 8.4331e-03 | Valid 8.8768e-03 | LR 1.000e-03 | Time 0.115s | Early stopping counter = 3
# Step   186 | Train 8.5187e-03 | Valid 1.0651e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 4
# Step   187 | Train 9.2682e-03 | Valid 1.0154e-02 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 5
# Step   188 | Train 8.4832e-03 | Valid 1.0134e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 6
# Step   189 | Train 9.9348e-03 | Valid 9.7551e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step   190 | Train 9.6072e-03 | Valid 9.8835e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 8
# Step   191 | Train 9.4634e-03 | Valid 8.8305e-03 | LR 1.000e-03 | Time 0.094s | Early stopping counter = 9
# Step   192 | Train 8.5966e-03 | Valid 9.8283e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 10
# Step   193 | Train 8.4460e-03 | Valid 8.2967e-03 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 11
# Step   194 | Train 8.7448e-03 | Valid 8.0570e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 12
# Step   195 | Train 8.7012e-03 | Valid 1.0267e-02 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 0
# Step   196 | Train 1.0353e-02 | Valid 8.4831e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 1
# Step   197 | Train 1.0049e-02 | Valid 1.0652e-02 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step   198 | Train 7.8918e-03 | Valid 8.9130e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 3
# Step   199 | Train 9.7059e-03 | Valid 8.0885e-03 | LR 1.000e-03 | Time 0.120s | Early stopping counter = 4
# Step   200 | Train 9.3223e-03 | Valid 1.0290e-02 | LR 1.000e-03 | Time 0.112s | Early stopping counter = 5
# Step   201 | Train 9.8500e-03 | Valid 9.7765e-03 | LR 1.000e-03 | Time 0.116s | Early stopping counter = 6
# Step   202 | Train 7.9084e-03 | Valid 7.6749e-03 | LR 1.000e-03 | Time 0.119s | Early stopping counter = 7
# Step   203 | Train 7.4857e-03 | Valid 9.9883e-03 | LR 1.000e-03 | Time 0.128s | Early stopping counter = 0
# Step   204 | Train 7.0537e-03 | Valid 8.2632e-03 | LR 1.000e-03 | Time 0.122s | Early stopping counter = 1
# Step   205 | Train 8.3556e-03 | Valid 7.1448e-03 | LR 1.000e-03 | Time 0.117s | Early stopping counter = 2
# Step   206 | Train 1.0139e-02 | Valid 8.8002e-03 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 0
# Step   207 | Train 7.3850e-03 | Valid 8.0363e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   208 | Train 9.0148e-03 | Valid 8.4386e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 2
# Step   209 | Train 8.5537e-03 | Valid 8.6200e-03 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 3
# Step   210 | Train 7.9600e-03 | Valid 7.3298e-03 | LR 1.000e-03 | Time 0.123s | Early stopping counter = 4
# Step   211 | Train 7.2016e-03 | Valid 7.7545e-03 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 5
# Step   212 | Train 6.9205e-03 | Valid 8.0116e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 6
# Step   213 | Train 8.0251e-03 | Valid 8.3223e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step   214 | Train 6.8874e-03 | Valid 8.4317e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 8
# Step   215 | Train 7.1908e-03 | Valid 6.0432e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 9
# Step   216 | Train 7.5624e-03 | Valid 7.3791e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   217 | Train 7.9652e-03 | Valid 7.9282e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step   218 | Train 7.0220e-03 | Valid 7.4409e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step   219 | Train 7.3373e-03 | Valid 7.3576e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 3
# Step   220 | Train 7.6259e-03 | Valid 7.6056e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 4
# Step   221 | Train 6.0760e-03 | Valid 7.9956e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 5
# Step   222 | Train 8.2355e-03 | Valid 7.1658e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 6
# Step   223 | Train 7.5312e-03 | Valid 8.5105e-03 | LR 1.000e-03 | Time 0.093s | Early stopping counter = 7
# Step   224 | Train 7.7469e-03 | Valid 5.8808e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 8
# Step   225 | Train 1.0151e-02 | Valid 6.7583e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 0
# Step   226 | Train 8.3687e-03 | Valid 8.4516e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step   227 | Train 8.5191e-03 | Valid 8.6399e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   228 | Train 6.8597e-03 | Valid 8.2311e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step   229 | Train 6.3823e-03 | Valid 6.5036e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 4
# Step   230 | Train 6.7760e-03 | Valid 7.2508e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 5
# Step   231 | Train 7.9704e-03 | Valid 7.1916e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 6
# Step   232 | Train 6.6427e-03 | Valid 7.1174e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step   233 | Train 8.5453e-03 | Valid 8.6801e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 8
# Step   234 | Train 6.2745e-03 | Valid 7.6186e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 9
# Step   235 | Train 6.9314e-03 | Valid 8.8543e-03 | LR 1.000e-03 | Time 0.105s | Early stopping counter = 10
# Step   236 | Train 7.5450e-03 | Valid 5.8441e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 11
# Step   237 | Train 6.1822e-03 | Valid 8.1579e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 0
# Step   238 | Train 5.2353e-03 | Valid 5.6816e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 1
# Step   239 | Train 6.9424e-03 | Valid 7.6091e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 0
# Step   240 | Train 6.8611e-03 | Valid 8.7322e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step   241 | Train 7.6678e-03 | Valid 6.6731e-03 | LR 1.000e-03 | Time 0.111s | Early stopping counter = 2
# Step   242 | Train 9.4330e-03 | Valid 5.6525e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step   243 | Train 6.9251e-03 | Valid 6.7758e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   244 | Train 8.2778e-03 | Valid 7.3614e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   245 | Train 7.7490e-03 | Valid 7.9828e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   246 | Train 6.9160e-03 | Valid 6.6745e-03 | LR 1.000e-03 | Time 0.126s | Early stopping counter = 3
# Step   247 | Train 6.5239e-03 | Valid 6.6256e-03 | LR 1.000e-03 | Time 0.115s | Early stopping counter = 4
# Step   248 | Train 6.2882e-03 | Valid 5.4865e-03 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 5
# Step   249 | Train 6.6030e-03 | Valid 5.7363e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   250 | Train 7.8580e-03 | Valid 7.3219e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 1
# Step   251 | Train 7.1004e-03 | Valid 5.8446e-03 | LR 1.000e-03 | Time 1.719s | Early stopping counter = 2
# Step   252 | Train 6.1204e-03 | Valid 7.3584e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 3
# Step   253 | Train 6.2465e-03 | Valid 7.5814e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 4
# Step   254 | Train 6.4340e-03 | Valid 7.1597e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 5
# Step   255 | Train 7.9475e-03 | Valid 6.7578e-03 | LR 1.000e-03 | Time 0.096s | Early stopping counter = 6
# Step   256 | Train 5.6053e-03 | Valid 7.6722e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 7
# Step   257 | Train 6.5584e-03 | Valid 7.1652e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 8
# Step   258 | Train 7.4244e-03 | Valid 6.0292e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 9
# Step   259 | Train 5.9165e-03 | Valid 6.0536e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 10
# Step   260 | Train 6.9137e-03 | Valid 5.4147e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 11
# Step   261 | Train 6.3399e-03 | Valid 8.1235e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   262 | Train 5.6937e-03 | Valid 7.6680e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   263 | Train 5.6007e-03 | Valid 5.6566e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step   264 | Train 5.9215e-03 | Valid 6.8587e-03 | LR 1.000e-03 | Time 0.113s | Early stopping counter = 3
# Step   265 | Train 6.2772e-03 | Valid 6.9185e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 4
# Step   266 | Train 6.6686e-03 | Valid 5.2389e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 5
# Step   267 | Train 6.5361e-03 | Valid 6.2514e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   268 | Train 7.7269e-03 | Valid 6.4364e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 1
# Step   269 | Train 5.4327e-03 | Valid 7.8044e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 2
# Step   270 | Train 5.8791e-03 | Valid 6.5839e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 3
# Step   271 | Train 5.6538e-03 | Valid 7.0036e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 4
# Step   272 | Train 6.2692e-03 | Valid 5.8819e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 5
# Step   273 | Train 6.0740e-03 | Valid 8.1553e-03 | LR 1.000e-03 | Time 0.110s | Early stopping counter = 6
# Step   274 | Train 6.1990e-03 | Valid 6.0475e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 7
# Step   275 | Train 6.9041e-03 | Valid 6.9946e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 8
# Step   276 | Train 6.3486e-03 | Valid 5.2338e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 9
# Step   277 | Train 5.7245e-03 | Valid 4.7124e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   278 | Train 6.4512e-03 | Valid 7.4033e-03 | LR 1.000e-03 | Time 0.114s | Early stopping counter = 0
# Step   279 | Train 5.6646e-03 | Valid 6.6460e-03 | LR 1.000e-03 | Time 0.122s | Early stopping counter = 1
# Step   280 | Train 6.2149e-03 | Valid 6.8088e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   281 | Train 6.5410e-03 | Valid 7.0378e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 3
# Step   282 | Train 8.2465e-03 | Valid 5.9118e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 4
# Step   283 | Train 4.8543e-03 | Valid 4.6937e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 5
# Step   284 | Train 4.9461e-03 | Valid 7.5431e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# Step   285 | Train 6.7746e-03 | Valid 5.6900e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step   286 | Train 6.0566e-03 | Valid 5.1241e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 2
# Step   287 | Train 6.8015e-03 | Valid 5.4020e-03 | LR 1.000e-03 | Time 0.092s | Early stopping counter = 3
# Step   288 | Train 5.9194e-03 | Valid 4.5940e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 4
# Step   289 | Train 6.8689e-03 | Valid 4.7352e-03 | LR 1.000e-03 | Time 0.106s | Early stopping counter = 0
# Step   290 | Train 5.6101e-03 | Valid 5.3314e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 1
# Step   291 | Train 5.8453e-03 | Valid 6.7970e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 2
# Step   292 | Train 6.9588e-03 | Valid 5.3130e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 3
# Step   293 | Train 6.4432e-03 | Valid 6.2224e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 4
# Step   294 | Train 7.0819e-03 | Valid 5.0887e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 5
# Step   295 | Train 5.4588e-03 | Valid 7.2028e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 6
# Step   296 | Train 6.6414e-03 | Valid 7.9371e-03 | LR 1.000e-03 | Time 0.109s | Early stopping counter = 7
# Step   297 | Train 7.0427e-03 | Valid 6.4805e-03 | LR 1.000e-03 | Time 0.107s | Early stopping counter = 8
# Step   298 | Train 5.3765e-03 | Valid 4.3101e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 9
# Step   299 | Train 6.9391e-03 | Valid 5.2075e-03 | LR 1.000e-03 | Time 0.108s | Early stopping counter = 0
# 16080 16080
# 16080 16080
# 2010 2010
# 2010 2010
# Step     0 | Train 4.9516e-03 | Valid 5.4946e-03 | LR 1.000e-04 | Time 0.833s | Early stopping counter = 0
# Step     1 | Train 5.4403e-03 | Valid 5.6741e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 0
# Step     2 | Train 5.6236e-03 | Valid 4.8935e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 1
# Step     3 | Train 5.8163e-03 | Valid 5.9167e-03 | LR 1.000e-04 | Time 0.114s | Early stopping counter = 0
# Step     4 | Train 4.5386e-03 | Valid 5.0049e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 1
# Step     5 | Train 5.3781e-03 | Valid 6.4186e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 2
# Step     6 | Train 6.9958e-03 | Valid 5.3902e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 3
# Step     7 | Train 6.6040e-03 | Valid 5.7271e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 4
# Step     8 | Train 5.4064e-03 | Valid 5.3266e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 5
# Step     9 | Train 6.3577e-03 | Valid 7.7583e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 6
# Step    10 | Train 4.5490e-03 | Valid 5.0992e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 7
# Step    11 | Train 4.9114e-03 | Valid 4.5395e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 8
# Step    12 | Train 5.8107e-03 | Valid 4.2381e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 0
# Step    13 | Train 4.6995e-03 | Valid 5.6525e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 0
# Step    14 | Train 5.8672e-03 | Valid 5.7717e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 1
# Step    15 | Train 5.6675e-03 | Valid 5.9847e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 2
# Step    16 | Train 6.1313e-03 | Valid 6.0295e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 3
# Step    17 | Train 5.3939e-03 | Valid 3.9732e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 4
# Step    18 | Train 6.2396e-03 | Valid 3.6546e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 0
# Step    19 | Train 6.3159e-03 | Valid 5.3946e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 0
# Step    20 | Train 5.4799e-03 | Valid 4.6145e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 1
# Step    21 | Train 5.3718e-03 | Valid 4.4168e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 2
# Step    22 | Train 4.8989e-03 | Valid 5.7914e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 3
# Step    23 | Train 6.0859e-03 | Valid 4.4276e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 4
# Step    24 | Train 7.3398e-03 | Valid 7.0791e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 5
# Step    25 | Train 6.1002e-03 | Valid 5.5488e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 6
# Step    26 | Train 6.3877e-03 | Valid 5.1656e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 7
# Step    27 | Train 5.2067e-03 | Valid 4.8321e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 8
# Step    28 | Train 4.8585e-03 | Valid 7.4521e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 9
# Step    29 | Train 6.6783e-03 | Valid 5.9633e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 10
# Step    30 | Train 6.8609e-03 | Valid 5.9912e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 11
# Step    31 | Train 4.0064e-03 | Valid 3.1464e-03 | LR 1.000e-04 | Time 0.093s | Early stopping counter = 12
# Step    32 | Train 3.9968e-03 | Valid 4.1794e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 0
# Step    33 | Train 6.9428e-03 | Valid 5.1675e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 1
# Step    34 | Train 5.4975e-03 | Valid 5.7345e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 2
# Step    35 | Train 7.0893e-03 | Valid 4.2649e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 3
# Step    36 | Train 4.9680e-03 | Valid 8.0157e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 4
# Step    37 | Train 3.7398e-03 | Valid 4.7186e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 5
# Step    38 | Train 4.9743e-03 | Valid 4.6005e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 6
# Step    39 | Train 3.6584e-03 | Valid 4.2584e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 7
# Step    40 | Train 6.4142e-03 | Valid 5.7327e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 8
# Step    41 | Train 6.3169e-03 | Valid 6.6908e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 9
# Step    42 | Train 6.5326e-03 | Valid 4.0628e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 10
# Step    43 | Train 4.6827e-03 | Valid 5.6683e-03 | LR 1.000e-04 | Time 0.111s | Early stopping counter = 11
# Step    44 | Train 5.6537e-03 | Valid 3.3294e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 12
# Step    45 | Train 4.8517e-03 | Valid 4.6019e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 13
# Step    46 | Train 5.1082e-03 | Valid 5.5898e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 14
# Step    47 | Train 5.6672e-03 | Valid 5.0894e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 15
# Step    48 | Train 5.6482e-03 | Valid 5.0865e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 16
# Step    49 | Train 6.4110e-03 | Valid 6.4294e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 17
# Step    50 | Train 5.4860e-03 | Valid 6.1982e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 18
# Step    51 | Train 6.3297e-03 | Valid 4.4716e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 19
# Step    52 | Train 4.9085e-03 | Valid 4.7953e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 20
# Step    53 | Train 4.7501e-03 | Valid 6.4105e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 21
# Step    54 | Train 5.0349e-03 | Valid 4.9190e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 22
# Step    55 | Train 5.7529e-03 | Valid 4.6280e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 23
# Step    56 | Train 4.6985e-03 | Valid 3.8966e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 24
# Step    57 | Train 5.9918e-03 | Valid 3.9407e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 25
# Step    58 | Train 5.3831e-03 | Valid 5.2431e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 26
# Step    59 | Train 5.0567e-03 | Valid 4.0025e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 27
# Step    60 | Train 5.4796e-03 | Valid 5.0521e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 28
# Step    61 | Train 5.6837e-03 | Valid 3.7811e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 29
# Step    62 | Train 6.3625e-03 | Valid 4.3672e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 30
# Step    63 | Train 3.8303e-03 | Valid 6.7788e-03 | LR 1.000e-04 | Time 0.094s | Early stopping counter = 31
# Step    64 | Train 4.2516e-03 | Valid 5.8501e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 32
# Step    65 | Train 5.0613e-03 | Valid 5.7923e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 33
# Step    66 | Train 4.0630e-03 | Valid 4.3963e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 34
# Step    67 | Train 5.8795e-03 | Valid 5.5711e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 35
# Step    68 | Train 6.2910e-03 | Valid 5.0362e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 36
# Step    69 | Train 5.6536e-03 | Valid 5.1155e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 37
# Step    70 | Train 5.5891e-03 | Valid 4.7507e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 38
# Step    71 | Train 5.0003e-03 | Valid 4.9721e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 39
# Step    72 | Train 5.3903e-03 | Valid 4.9428e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 40
# Step    73 | Train 6.5290e-03 | Valid 4.4620e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 41
# Step    74 | Train 5.9815e-03 | Valid 4.7433e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 42
# Step    75 | Train 5.6389e-03 | Valid 4.4372e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 43
# Step    76 | Train 5.3130e-03 | Valid 5.0732e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 44
# Step    77 | Train 4.8591e-03 | Valid 5.9101e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 45
# Step    78 | Train 5.1855e-03 | Valid 4.4283e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 46
# Step    79 | Train 4.5763e-03 | Valid 3.2152e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 47
# Step    80 | Train 3.9948e-03 | Valid 4.2028e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 48
# Step    81 | Train 3.6988e-03 | Valid 5.0230e-03 | LR 1.000e-04 | Time 0.123s | Early stopping counter = 49
# Step    82 | Train 5.4642e-03 | Valid 4.8427e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 50
# Step    83 | Train 4.4762e-03 | Valid 4.2420e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 51
# Step    84 | Train 3.7243e-03 | Valid 5.1757e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 52
# Step    85 | Train 5.8694e-03 | Valid 3.6299e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 53
# Step    86 | Train 5.5141e-03 | Valid 4.1254e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 54
# Step    87 | Train 5.9195e-03 | Valid 5.8611e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 55
# Step    88 | Train 4.2623e-03 | Valid 4.3669e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 56
# Step    89 | Train 3.8787e-03 | Valid 3.5950e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 57
# Step    90 | Train 4.8092e-03 | Valid 5.7711e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 58
# Step    91 | Train 4.4241e-03 | Valid 6.0606e-03 | LR 1.000e-04 | Time 0.114s | Early stopping counter = 59
# Step    92 | Train 4.9166e-03 | Valid 2.7692e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 60
# Step    93 | Train 5.8587e-03 | Valid 3.1386e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 0
# Step    94 | Train 4.9202e-03 | Valid 4.7014e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 1
# Step    95 | Train 4.5085e-03 | Valid 5.5534e-03 | LR 1.000e-04 | Time 0.092s | Early stopping counter = 2
# Step    96 | Train 5.5272e-03 | Valid 5.2720e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 3
# Step    97 | Train 4.2073e-03 | Valid 6.8031e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 4
# Step    98 | Train 5.5204e-03 | Valid 4.7889e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 5
# Step    99 | Train 4.2391e-03 | Valid 4.6747e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 6
# Step   100 | Train 4.5589e-03 | Valid 5.5719e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 7
# Step   101 | Train 3.7525e-03 | Valid 4.0934e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 8
# Step   102 | Train 4.5351e-03 | Valid 5.0384e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 9
# Step   103 | Train 5.4329e-03 | Valid 6.0033e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 10
# Step   104 | Train 6.2804e-03 | Valid 4.9631e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 11
# Step   105 | Train 6.4435e-03 | Valid 5.9856e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 12
# Step   106 | Train 4.8253e-03 | Valid 2.9874e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 13
# Step   107 | Train 5.5613e-03 | Valid 4.8991e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 14
# Step   108 | Train 4.8568e-03 | Valid 5.0573e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 15
# Step   109 | Train 5.8607e-03 | Valid 6.3936e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 16
# Step   110 | Train 3.8562e-03 | Valid 2.6100e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 17
# Step   111 | Train 3.9858e-03 | Valid 2.8702e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 0
# Step   112 | Train 4.0054e-03 | Valid 5.9543e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 1
# Step   113 | Train 6.3713e-03 | Valid 3.5430e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 2
# Step   114 | Train 4.2943e-03 | Valid 4.7772e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 3
# Step   115 | Train 3.5587e-03 | Valid 4.7119e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 4
# Step   116 | Train 3.7457e-03 | Valid 5.2194e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 5
# Step   117 | Train 5.2797e-03 | Valid 3.1082e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 6
# Step   118 | Train 5.3178e-03 | Valid 3.3825e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 7
# Step   119 | Train 3.7442e-03 | Valid 4.4817e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 8
# Step   120 | Train 4.1965e-03 | Valid 4.3826e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 9
# Step   121 | Train 4.3062e-03 | Valid 2.5959e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 10
# Step   122 | Train 5.4446e-03 | Valid 6.0580e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 0
# Step   123 | Train 6.3953e-03 | Valid 3.3807e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 1
# Step   124 | Train 5.1688e-03 | Valid 4.8966e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 2
# Step   125 | Train 4.9915e-03 | Valid 5.1221e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 3
# Step   126 | Train 5.8718e-03 | Valid 2.3794e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 4
# Step   127 | Train 5.2502e-03 | Valid 4.4607e-03 | LR 1.000e-04 | Time 0.093s | Early stopping counter = 0
# Step   128 | Train 4.5813e-03 | Valid 5.6307e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 1
# Step   129 | Train 4.0308e-03 | Valid 3.0469e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 2
# Step   130 | Train 5.3837e-03 | Valid 6.5207e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 3
# Step   131 | Train 5.0278e-03 | Valid 3.7377e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 4
# Step   132 | Train 5.0114e-03 | Valid 4.0306e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 5
# Step   133 | Train 4.8424e-03 | Valid 5.6627e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 6
# Step   134 | Train 3.3172e-03 | Valid 3.5858e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 7
# Step   135 | Train 5.1452e-03 | Valid 3.5612e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 8
# Step   136 | Train 5.3518e-03 | Valid 3.5365e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 9
# Step   137 | Train 4.6753e-03 | Valid 3.3278e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 10
# Step   138 | Train 5.1157e-03 | Valid 5.9498e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 11
# Step   139 | Train 6.1918e-03 | Valid 5.6939e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 12
# Step   140 | Train 4.1157e-03 | Valid 5.0160e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 13
# Step   141 | Train 4.5919e-03 | Valid 3.7094e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 14
# Step   142 | Train 6.0372e-03 | Valid 4.9749e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 15
# Step   143 | Train 5.6813e-03 | Valid 4.3435e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 16
# Step   144 | Train 5.6281e-03 | Valid 3.5197e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 17
# Step   145 | Train 5.6968e-03 | Valid 3.1545e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 18
# ...
# Step   152 | Train 5.6441e-03 | Valid 4.0119e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 25
# Step   153 | Train 4.8850e-03 | Valid 4.0059e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 26
# Step   154 | Train 4.9979e-03 | Valid 3.3611e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 27
# Step   155 | Train 4.3714e-03 | Valid 4.8704e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 28
# Step   156 | Train 3.7422e-03 | Valid 4.6860e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 29
# Step   157 | Train 6.2405e-03 | Valid 4.5443e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 30
# Step   158 | Train 4.5457e-03 | Valid 4.7385e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 31
# Step   159 | Train 5.7659e-03 | Valid 6.8167e-03 | LR 1.000e-04 | Time 0.104s | Early stopping counter = 32
# Step   160 | Train 5.2796e-03 | Valid 5.5719e-03 | LR 1.000e-04 | Time 0.114s | Early stopping counter = 33
# Step   161 | Train 5.2563e-03 | Valid 4.2413e-03 | LR 1.000e-04 | Time 0.111s | Early stopping counter = 34
# Step   162 | Train 4.1674e-03 | Valid 4.1933e-03 | LR 1.000e-04 | Time 0.124s | Early stopping counter = 35
# Step   163 | Train 4.8346e-03 | Valid 3.0511e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 36
# Step   164 | Train 5.3294e-03 | Valid 4.9974e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 37
# Step   165 | Train 4.5695e-03 | Valid 4.4064e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 38
# Step   166 | Train 6.1994e-03 | Valid 4.0958e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 39
# Step   167 | Train 4.3080e-03 | Valid 4.1186e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 40
# Step   168 | Train 4.9288e-03 | Valid 5.1545e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 41
# Step   169 | Train 4.9492e-03 | Valid 4.0318e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 42
# Step   170 | Train 4.1119e-03 | Valid 3.9119e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 43
# Step   171 | Train 4.6008e-03 | Valid 3.9145e-03 | LR 1.000e-04 | Time 0.116s | Early stopping counter = 44
# Step   172 | Train 3.6883e-03 | Valid 4.7497e-03 | LR 1.000e-04 | Time 0.113s | Early stopping counter = 45
# Step   173 | Train 6.4146e-03 | Valid 4.6959e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 46
# Step   174 | Train 5.2923e-03 | Valid 5.1593e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 47
# Step   175 | Train 7.2014e-03 | Valid 5.2599e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 48
# Step   176 | Train 4.5477e-03 | Valid 4.4279e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 49
# Step   177 | Train 5.9048e-03 | Valid 3.6635e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 50
# Step   178 | Train 4.1697e-03 | Valid 3.7029e-03 | LR 1.000e-04 | Time 0.133s | Early stopping counter = 51
# Step   179 | Train 5.4396e-03 | Valid 4.0831e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 52
# Step   180 | Train 4.7993e-03 | Valid 4.3519e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 53
# Step   181 | Train 5.0923e-03 | Valid 3.7125e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 54
# Step   182 | Train 3.5318e-03 | Valid 4.1810e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 55
# Step   183 | Train 4.7460e-03 | Valid 4.6550e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 56
# Step   184 | Train 6.1029e-03 | Valid 4.9379e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 57
# Step   185 | Train 3.9430e-03 | Valid 2.7079e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 58
# Step   186 | Train 3.7574e-03 | Valid 3.4676e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 59
# Step   187 | Train 4.8767e-03 | Valid 5.0997e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 60
# Step   188 | Train 4.6419e-03 | Valid 4.2305e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 61
# Step   189 | Train 4.9272e-03 | Valid 5.2691e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 62
# Step   190 | Train 5.4503e-03 | Valid 4.2472e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 63
# Step   191 | Train 5.4593e-03 | Valid 4.1981e-03 | LR 1.000e-04 | Time 0.093s | Early stopping counter = 64
# Step   192 | Train 4.3896e-03 | Valid 4.4007e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 65
# Step   193 | Train 4.7112e-03 | Valid 3.6645e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 66
# Step   194 | Train 4.3033e-03 | Valid 4.1140e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 67
# Step   195 | Train 4.3411e-03 | Valid 4.5571e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 68
# Step   196 | Train 5.0026e-03 | Valid 4.3274e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 69
# Step   197 | Train 6.7988e-03 | Valid 5.4655e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 70
# Step   198 | Train 3.4032e-03 | Valid 4.6726e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 71
# Step   199 | Train 5.8206e-03 | Valid 2.7513e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 72
# Step   200 | Train 4.5781e-03 | Valid 6.4863e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 73
# Step   201 | Train 6.8395e-03 | Valid 5.3151e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 74
# Step   202 | Train 4.2349e-03 | Valid 3.5297e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 75
# Step   203 | Train 3.6940e-03 | Valid 5.4874e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 76
# Step   204 | Train 3.4054e-03 | Valid 4.0698e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 77
# Step   205 | Train 4.8367e-03 | Valid 3.2447e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 78
# Step   206 | Train 6.3710e-03 | Valid 3.9295e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 79
# Step   207 | Train 3.3027e-03 | Valid 4.9788e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 80
# Step   208 | Train 5.3628e-03 | Valid 4.5677e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 81
# Step   209 | Train 5.0464e-03 | Valid 4.3685e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 82
# Step   210 | Train 5.3717e-03 | Valid 3.4228e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 83
# Step   211 | Train 4.1210e-03 | Valid 4.2423e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 84
# Step   212 | Train 4.6415e-03 | Valid 4.7007e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 85
# Step   213 | Train 4.7486e-03 | Valid 4.7705e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 86
# Step   214 | Train 4.3660e-03 | Valid 4.6889e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 87
# Step   215 | Train 4.1669e-03 | Valid 2.2677e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 88
# Step   216 | Train 4.8046e-03 | Valid 3.7131e-03 | LR 1.000e-04 | Time 0.105s | Early stopping counter = 0
# Step   217 | Train 4.8964e-03 | Valid 3.7273e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 1
# Step   218 | Train 4.2967e-03 | Valid 3.5308e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 2
# Step   219 | Train 4.0303e-03 | Valid 4.3116e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 3
# Step   220 | Train 4.7749e-03 | Valid 4.3685e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 4
# Step   221 | Train 3.2488e-03 | Valid 4.4368e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 5
# Step   222 | Train 5.4308e-03 | Valid 3.6977e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 6
# Step   223 | Train 5.0389e-03 | Valid 5.6486e-03 | LR 1.000e-04 | Time 0.094s | Early stopping counter = 7
# Step   224 | Train 3.7796e-03 | Valid 3.1663e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 8
# Step   225 | Train 6.7107e-03 | Valid 4.0262e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 9
# Step   226 | Train 5.7006e-03 | Valid 5.5744e-03 | LR 1.000e-04 | Time 0.113s | Early stopping counter = 10
# Step   227 | Train 5.6536e-03 | Valid 4.9614e-03 | LR 1.000e-04 | Time 0.111s | Early stopping counter = 11
# Step   228 | Train 5.3833e-03 | Valid 4.4948e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 12
# Step   229 | Train 3.6532e-03 | Valid 3.6089e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 13
# Step   230 | Train 4.6122e-03 | Valid 4.4800e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 14
# Step   231 | Train 5.8305e-03 | Valid 4.8846e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 15
# Step   232 | Train 4.0266e-03 | Valid 4.3728e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 16
# Step   233 | Train 5.9365e-03 | Valid 5.9497e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 17
# Step   234 | Train 4.6250e-03 | Valid 4.4484e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 18
# Step   235 | Train 4.5085e-03 | Valid 6.1182e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 19
# Step   236 | Train 5.5315e-03 | Valid 3.2998e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 20
# Step   237 | Train 4.1218e-03 | Valid 4.2281e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 21
# Step   238 | Train 3.3521e-03 | Valid 3.7846e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 22
# Step   239 | Train 4.8812e-03 | Valid 3.9665e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 23
# Step   240 | Train 4.1623e-03 | Valid 5.3521e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 24
# Step   241 | Train 5.2374e-03 | Valid 3.8107e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 25
# Step   242 | Train 6.8200e-03 | Valid 2.7785e-03 | LR 1.000e-04 | Time 0.111s | Early stopping counter = 26
# Step   243 | Train 5.0551e-03 | Valid 4.0477e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 27
# Step   244 | Train 5.4504e-03 | Valid 4.7252e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 28
# Step   245 | Train 5.9750e-03 | Valid 4.9658e-03 | LR 1.000e-04 | Time 0.110s | Early stopping counter = 29
# Step   246 | Train 4.4922e-03 | Valid 3.4472e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 30
# Step   247 | Train 3.8480e-03 | Valid 3.3130e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 31
# Step   248 | Train 4.2051e-03 | Valid 3.4619e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 32
# Step   249 | Train 4.8641e-03 | Valid 3.2365e-03 | LR 1.000e-04 | Time 0.128s | Early stopping counter = 33
# Step   250 | Train 5.6335e-03 | Valid 4.6704e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 34
# Step   251 | Train 5.2460e-03 | Valid 2.5263e-03 | LR 1.000e-04 | Time 1.602s | Early stopping counter = 35
# Step   252 | Train 4.3067e-03 | Valid 4.0933e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 36
# Step   253 | Train 4.2351e-03 | Valid 4.9718e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 37
# Step   254 | Train 4.5110e-03 | Valid 5.1550e-03 | LR 1.000e-04 | Time 0.112s | Early stopping counter = 38
# Step   255 | Train 5.5776e-03 | Valid 4.7045e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 39
# Step   256 | Train 3.6095e-03 | Valid 5.6100e-03 | LR 1.000e-04 | Time 0.112s | Early stopping counter = 40
# Step   257 | Train 5.1271e-03 | Valid 4.7112e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 41
# Step   258 | Train 4.9145e-03 | Valid 4.0693e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 42
# Step   259 | Train 4.2608e-03 | Valid 3.7934e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 43
# Step   260 | Train 4.6676e-03 | Valid 3.1184e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 44
# Step   261 | Train 4.3863e-03 | Valid 5.2893e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 45
# Step   262 | Train 3.6927e-03 | Valid 4.7595e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 46
# Step   263 | Train 3.6591e-03 | Valid 3.2831e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 47
# Step   264 | Train 4.3888e-03 | Valid 3.8990e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 48
# Step   265 | Train 4.8013e-03 | Valid 4.4245e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 49
# Step   266 | Train 4.4486e-03 | Valid 2.9708e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 50
# Step   267 | Train 4.8547e-03 | Valid 4.2096e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 51
# Step   268 | Train 6.3032e-03 | Valid 3.9672e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 52
# Step   269 | Train 3.6532e-03 | Valid 5.9163e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 53
# Step   270 | Train 4.6225e-03 | Valid 3.7862e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 54
# Step   271 | Train 3.7020e-03 | Valid 4.7802e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 55
# Step   272 | Train 4.4222e-03 | Valid 3.7102e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 56
# Step   273 | Train 4.3161e-03 | Valid 5.7107e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 57
# Step   274 | Train 4.3500e-03 | Valid 4.1188e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 58
# Step   275 | Train 4.7128e-03 | Valid 4.9067e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 59
# Step   276 | Train 4.6174e-03 | Valid 3.6589e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 60
# Step   277 | Train 4.4180e-03 | Valid 2.7969e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 61
# Step   278 | Train 4.6490e-03 | Valid 4.7685e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 62
# Step   279 | Train 3.7963e-03 | Valid 4.1075e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 63
# Step   280 | Train 4.2038e-03 | Valid 4.5914e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 64
# Step   281 | Train 5.0825e-03 | Valid 4.4896e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 65
# Step   282 | Train 6.0802e-03 | Valid 4.1859e-03 | LR 1.000e-04 | Time 0.114s | Early stopping counter = 66
# Step   283 | Train 3.3642e-03 | Valid 2.4079e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 67
# Step   284 | Train 3.4295e-03 | Valid 5.6624e-03 | LR 1.000e-04 | Time 0.109s | Early stopping counter = 68
# Step   285 | Train 5.5287e-03 | Valid 4.1600e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 69
# Step   286 | Train 4.6824e-03 | Valid 3.2104e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 70
# Step   287 | Train 5.1937e-03 | Valid 2.5587e-03 | LR 1.000e-04 | Time 0.092s | Early stopping counter = 71
# Step   288 | Train 4.5417e-03 | Valid 3.2297e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 72
# Step   289 | Train 5.6506e-03 | Valid 2.4450e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 73
# Step   290 | Train 4.0265e-03 | Valid 3.2792e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 74
# Step   291 | Train 3.9206e-03 | Valid 4.4381e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 75
# Step   292 | Train 5.2112e-03 | Valid 3.1115e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 76
# Step   293 | Train 4.7420e-03 | Valid 4.5685e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 77
# Step   294 | Train 5.0859e-03 | Valid 3.3194e-03 | LR 1.000e-04 | Time 0.106s | Early stopping counter = 78
# Step   295 | Train 4.0212e-03 | Valid 4.1713e-03 | LR 1.000e-04 | Time 0.111s | Early stopping counter = 79
# Step   296 | Train 4.6296e-03 | Valid 5.2133e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 80
# Step   297 | Train 5.2028e-03 | Valid 4.8606e-03 | LR 1.000e-04 | Time 0.108s | Early stopping counter = 81
# Step   298 | Train 3.9253e-03 | Valid 2.7155e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 82
# Step   299 | Train 5.1353e-03 | Valid 3.9274e-03 | LR 1.000e-04 | Time 0.107s | Early stopping counter = 83

# %%
Utest_POD_hat_2= jax.vmap(shred_2)(test_data['S_i'])
print("Utest_POD_hat shape:", Utest_POD_hat_2.shape)
Utest_hat_2 = torch.from_numpy(scalerU.inverse_transform(Utest_POD_hat_2)) @ V
Utest_hat_2 = Utest_hat_2.reshape(ntest, ntimes, nstate)

print("Mean relative SHRED prediction error on U with diffrax: %s" % num2p(mre(Utest, Utest_hat_2)))
print("Mean relative SHRED prediction error on U with pytorch: %s" % num2p(mre(Utest, Utest_hat)))
# Out:
# Utest_POD_hat shape: (2010, 20)
# Mean relative SHRED prediction error on U with diffrax: 36.30%
# Mean relative SHRED prediction error on U with pytorch: 10.77%
# /var/folders/tt/h2vsggv50cv7_km1_pmr2nn00000gn/T/ipykernel_5522/1543675726.py:3: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   Utest_hat_2 = torch.from_numpy(scalerU.inverse_transform(Utest_POD_hat_2)) @ V

# %%
which = np.random.randint(0, ntest)

plotlist = [Utest[which], Utest_hat[which], Utest_hat_2[which], ((Utest[which] - Utest_hat[which])**2).sqrt(), ((Utest[which] - Utest_hat_2[which])**2).sqrt()]

trajectories_with_sensors(plotlist, sensors_coordinates, titles = ("State trajectory", "SHRED prediction pytorch", "SHRED prediction diffrax","Prediction error pytorch", "Prediction error diffrax "), fontsize = 16, ticks = False)
